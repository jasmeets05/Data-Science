# %%
pip install googlesearch-python
# Out:
# Requirement already satisfied: googlesearch-python in c:\users\jass\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: beautifulsoup4>=4.9 in c:\users\jass\anaconda3\lib\site-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: requests>=2.20 in c:\users\jass\anaconda3\lib\site-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jass\anaconda3\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jass\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jass\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jass\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jass\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googlesearch import search
title = 'dog'
data = search(title,num_results=10)

all_data = []

for i in data:
  all_data.append(i+'\n')

file = open(f'{title}.txt',mode = 'w')
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
from googlesearch import search

title = 'ai ml'

data = search(title,num_results=10)

all_data = []

for i in data:
  all_data.append(i+'\n')

file = open(f'{title}.txt',mode = 'x')
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
from googlesearch import search

title = 'chat gpt trending news in investments'

data = search(title,num_results=5)

all_data = []

for i in data:
  all_data.append(i+'\n')

file = open(f'{title}.txt',mode = 'a')
file.write('=========================================================================================\n')
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
#mode = w+

# %% [markdown]
# # file handling

# %%
#binary dile data = bytes format

# %%
#copy data from binary file and create a new one

# %%
path = r'''C:\Users\Jass\Downloads\pexels-njeromin-17726838.jpg''' #r = read it as it written
file = open(path,mode = 'rb')
data = file.read()
print('done')
# Out:
# done

# %%
type(data)
# Out:
# bytes

# %%
file
# Out:
# <_io.BufferedReader name='C:\\Users\\Jass\\Downloads\\pexels-njeromin-17726838.jpg'>

# %%
print(data[:500])
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x01\x00H\x00H\x00\x00\xff\xe2\x0cXICC_PROFILE\x00\x01\x01\x00\x00\x0cHLino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x84\x00\x00\x00lwtpt\x00\x00\x01\xf0\x00\x00\x00\x14bkpt\x00\x00\x02\x04\x00\x00\x00\x14rXYZ\x00\x00\x02\x18\x00\x00\x00\x14gXYZ\x00\x00\x02,\x00\x00\x00\x14bXYZ\x00\x00\x02@\x00\x00\x00\x14dmnd\x00\x00\x02T\x00\x00\x00pdmdd\x00\x00\x02\xc4\x00\x00\x00\x88vued\x00\x00\x03L\x00\x00\x00\x86view\x00\x00\x03\xd4\x00\x00\x00$lumi\x00\x00\x03\xf8\x00\x00\x00\x14meas\x00\x00\x04\x0c\x00\x00\x00$tech\x00\x00\x040\x00\x00\x00\x0crTRC\x00\x00\x04<\x00\x00\x08\x0cgTRC\x00\x00\x04<\x00\x00\x08\x0cbTRC\x00\x00\x04<\x00\x00\x08\x0ctext\x00\x00\x00\x00Copyright (c) 1998 Hewlett-Packard Company\x00\x00desc\x00\x00\x00\x00\x00\x00\x00\x12sRGB IEC61966-2.1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x12sRGB IEC61966-2.1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
f =open('image.jpg', mode = 'wb')
f.write(data)
f.close()
print('done')
# Out:
# done

# %%
url = '''https://images.pexels.com/photos/618833/pexels-photo-618833.jpeg?cs=srgb&dl=pexels-sagui-andrea-200115-618833.jpg&fm=jpg'''

import requests as r
image_data = r.get(url).content
type(image_data)
# Out:
# bytes

# %%
f = open('download_image.jpg','wb')
f.write(image_data)
f.close()

from IPython import display
display.Image('download_image.jpg')

# %%
url= '''https://picsum.photos/1080/720'''

import requests as r
n= 10
for i in range(n):
    img_data = r.get(url).content
    f = open(f'image_{i}.jpg','wb')
    f.write(img_data)
    f.close()
    from IPython import display as d
    display(d.Image(f'image_{i}.jpg',width = 700,height = 700))

# %%
url_path = '''https://www.python.org/ftp/python/3.13.5/python-3.13.5-amd64.exe'''

# context manager
import requests as r
with open(r'C:\Users\Jass\OneDrive\Desktop\data science\js.exe','wb') as file:
    file.write(r.get(url_path).content)

print('Done')
# Out:
# Done
